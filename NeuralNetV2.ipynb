# %%
import numpy as np 
import pandas as pd
import random

# %%
train_x = pd.read_csv("./data/processed_x.csv", delimiter=",", header = None) # load from processed images

# %%
train_y = pd.read_csv("./data/train_y.csv", delimiter = ",", header = None)

# %%
def sigmoid(z):
    return 1.0/(1.0 + np.exp(-z))

def derivatives_sigmoid(z):
    """Derivative of the sigmoid function."""
    return sigmoid(z)*(1-sigmoid(z))

# %%
X = train_x.head(100).values
Y = train_y.head(100).values
printY = train_y.head(100)
printY = np.array(map(int, printY[0].tolist()))
# Y = Y.reshape((Y.shape[0],1))
newY = np.zeros((Y.shape[0], 10))
for i in range(len(Y)):
    temp = np.zeros(10)
    temp[Y[i]] = 1
    newY[i] = temp

# %%
epoch=1000 #Setting training iterations
lr=0.1 #Setting learning rate
inputlayer_neurons = X.shape[1] #number of features in data set
hiddenlayer_neurons = 30 #number of hidden layers neurons
output_neurons = 10 #number of neurons at output layer

# %%
#weight and bias initialization
# wh=np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))
# bh=np.random.uniform(size=(1,hiddenlayer_neurons))
# wout=np.random.uniform(size=(hiddenlayer_neurons,output_neurons))
# bout=np.random.uniform(size=(1,output_neurons))

wh=np.random.randn(inputlayer_neurons,hiddenlayer_neurons)
bh=np.random.randn(1,hiddenlayer_neurons)
wout=np.random.randn(hiddenlayer_neurons,output_neurons)
bout=np.random.randn(1,output_neurons)

# %%
for i in range(100):

    #Forward Propogation
    
    # first layer
    hidden_layer_input1=np.dot(X,wh)
    hidden_layer_input=hidden_layer_input1 + bh
    hiddenlayer_activations = sigmoid(hidden_layer_input)
    
    #last layer
    output_layer_input1=np.dot(hiddenlayer_activations,wout)
    output_layer_input= output_layer_input1 + bout
    output = sigmoid(output_layer_input)

    #Backpropagation
    E = newY-output
    slope_output_layer = derivatives_sigmoid(output)
    slope_hidden_layer = derivatives_sigmoid(hiddenlayer_activations)
    d_output = E * slope_output_layer
    Error_at_hidden_layer = d_output.dot(wout.T)
    d_hiddenlayer = Error_at_hidden_layer * slope_hidden_layer
    
    wout += hiddenlayer_activations.T.dot(d_output) *lr
    bout += np.sum(d_output, axis=0,keepdims=True) *lr
    wh += X.T.dot(d_hiddenlayer) *lr
    bh += np.sum(d_hiddenlayer, axis=0,keepdims=True) *lr

# print output
# results = [np.argmax(x) for x in output]
# print printY
# print results
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
#feed forward
X = train_x.tail(100).values
Y = train_y.tail(100)
Y = np.array(map(int, Y[0].tolist()))
print Y
a = sigmoid(np.dot(X, wh)+bh)
a = sigmoid(np.dot(a, wout)+bout)
results = [np.argmax(x) for x in a]
print results
print a
# Out:
# [7 1 3 9 5 4 0 5 0 2 5 9 6 3 9 5 7 1 7 4 5 3 8 6 4 9 3 1 8 2 4 6 3 5 3 6 5
#  6 3 6 4 2 2 7 7 4 2 3 9 3 3 9 2 6 7 2 4 8 3 9 2 5 8 9 1 5 4 1 4 0 8 6 3 9
#  0 7 9 4 9 9 2 6 3 9 2 1 0 7 5 3 2 4 6 9 7 1 7 3 7 9]
# [4, 8, 1, 8, 8, 8, 4, 8, 0, 8, 8, 0, 0, 0, 4, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 0, 8, 8, 0, 0, 8, 5, 4, 8, 8, 8, 8, 8, 0, 4, 3, 8, 3, 8, 8, 4, 8, 6, 6, 8, 8, 8, 8, 1, 8, 6, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 6, 8, 4, 1, 8, 8, 0, 6, 8, 0, 4, 8, 8, 8, 8, 8, 4, 8, 4, 8, 8, 4, 3, 8, 8, 8]
# [[7.89871234e-02 9.66693535e-03 1.40349360e-02 1.05922039e-02
#   3.94553596e-01 7.83925895e-03 1.46485270e-02 1.70970778e-01
#   2.95446501e-01 9.87226340e-03]
#  [1.10923657e-01 7.82360598e-02 6.59261255e-02 8.55246379e-02
#   7.63847217e-02 6.09795590e-02 1.03225315e-01 1.07451012e-01
#   1.52605169e-01 9.81445929e-02]
#  [2.37758903e-01 6.89847806e-01 8.04051953e-03 2.40288792e-01
#   9.30858631e-02 1.77949938e-03 6.72640689e-02 9.49287539e-03
# ...

# %%
print bh
print wh
# Out:
# [[-1.45341026 -3.27626662 -0.21986959  1.30357891 -0.41322483 -0.16695137
#   -1.55931165 -1.74281347 -0.84334112 -0.97545143  0.10945789 -3.5073261
#    0.50112945 -0.76335028 -0.50890725 -0.28910999  0.57092919  0.01111281
#   -0.25452289 -1.87755056 -2.37435318 -1.58134703  0.56676823  0.12620469
#   -3.61367785 -0.92791154 -0.20670902 -0.62602691 -0.23361578 -1.65622181]]
# [[-115.30378245 -645.88012726 -132.52814776 ... -210.47861841
#    -23.56924941  -65.9546934 ]
#  [-116.78499895 -646.8641828  -136.9803424  ... -208.61936002
#    -23.8786442   -69.13564653]
#  [-114.88740805 -647.29436182 -132.48165396 ... -208.91283955
#    -24.55305225  -68.59623857]
#  ...
#  [-114.75696047 -646.63930291 -136.55478616 ... -210.35948367
#    -25.98229981  -69.22524915]
#  [-116.29817794 -647.9610994  -134.99705086 ... -208.66603387
#    -26.21080524  -70.70124669]
#  [-116.12388954 -647.0650919  -135.14942348 ... -208.90579269
#    -23.92885526  -70.69378949]]
